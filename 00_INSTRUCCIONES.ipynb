# %% [markdown]
# # **Instrucciones para ejecutar el notebook**

# %% [markdown]
#  **Fuente de datos:**
#
# Datos tomados de Kaggle, los cuales son el producto de una simulación de transacciones de dinero móvil, basadas en una muestra de transacciones reales extraídas de un mes de registros financieros, implementado en un país africano. Los registros originales fueron proporcionados por una empresa multinacional, proveedor del servicio financiero móvil.

# %% [markdown]
# **1. Instala Kaggle**

# %%
! pip install -q kaggle

# %% [markdown]
# **2. Registro en Kaggle**
#
# Debes registrarte en Kaggle.
# https://www.kaggle.com

# %% [markdown]
# **3. Descargar api token**
#
# Ingresar a Kaggle con usuario y contraseña. En el perfil ingresar a la opción: account como te mostramos a continuación

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **4. Crea un api token**
#
# crear un nuevo api token, el cual descargará un archivo .json, necesario para la conexión y descarga de los datos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **5. Descarga de usuario y contraseña de kaggle**
#
# El archivo .json te dará tu usuario y contraseña para acceder a las bases de kaggle, ejemplo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **6. Ejecución del notebook 01-MONOGRAFIA DETECCION DE FRAUDE.ipynb**
#
# Ya puedes comenzar a ejecutar el desarrollo de la monografía
